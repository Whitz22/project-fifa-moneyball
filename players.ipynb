# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Fifa = pd.read_csv("Fifa 23 Players Data.csv")
Fifa
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  LM Rating  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         86
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         92
# ...                                                 ...  ...  ...        ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...         50
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...         45
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...         52
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...         33
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...         44
#
#        CM Rating  RM Rating  LWB Rating CDM Rating  RWB Rating  LB Rating  \
# 0             88         91          67         66          67         62
# 1             84         89          67         67          67         63
# 2             83         86          67         69          67         64
# 3             91         91          82         82          82         78
# 4             84         92          70         66          70         66
# ...          ...        ...         ...        ...         ...        ...
# 18534         44         50          41         38          41         40
# 18535         45         45          47         48          47         49
# 18536         49         52          46         44          46         46
# 18537         33         33          44         42          44         47
# 18538         40         44          46         43          46         47
#
#       CB Rating RB Rating GK Rating
# 0            53        62        22
# 1            58        63        21
# 2            63        64        22
# 3            72        78        24
# 4            57        66        21
# ...         ...       ...       ...
# 18534        36        40        15
# 18535        49        49        15
# 18536        42        46        17
# 18537        49        47        15
# 18538        47        47        19
#
# [18539 rows x 89 columns]

# %%
# Cleaning the data by selecting the columns we will use for our analysis.

Fifa_Cle = Fifa[['Known As', 'Overall', 'Potential', 'Value(in Euro)',
       'Positions Played', 'Best Position', 'Age',
       'Height(in cm)', 'Weight(in kg)',
       'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
       'Contract Until', 'Joined On', 'On Loan', 'National Team Name','ST Rating',
       'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
       'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
       'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
       'GK Rating','Nationality']]

# %%
# Add a column to understand the potential gap of each player.

Fifa_Cle["Gap_Potential"] = Fifa_Cle["Potential"] - Fifa_Cle["Overall"]
Fifa_Cle
# Out:
# C:\Users\withl\AppData\Local\Temp\ipykernel_18512\1567703331.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_Cle["Gap_Potential"] = Fifa_Cle["Potential"] - Fifa_Cle["Overall"]
#              Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 0            L. Messi       91         91        54000000               RW
# 1          K. Benzema       91         91        64000000            CF,ST
# 2      R. Lewandowski       91         91        84000000               ST
# 3        K. De Bruyne       91         91       107500000           CM,CAM
# 4           K. Mbappé       91         95       190500000            ST,LW
# ...               ...      ...        ...             ...              ...
# 18534      D. Collins       47         56          110000            ST,RM
# 18535    Yang Dejiang       47         57           90000              CDM
# 18536       L. Mullan       47         67          130000               CM
# 18537    D. McCallion       47         61          100000               CB
# 18538        N. Rabha       47         50           60000               LB
#
#       Best Position  Age  Height(in cm)  Weight(in kg)            Club Name  \
# 0               CAM   35            169             67  Paris Saint-Germain
# 1                CF   34            185             81       Real Madrid CF
# 2                ST   33            185             81         FC Barcelona
# 3                CM   31            181             70      Manchester City
# 4                ST   23            182             73  Paris Saint-Germain
# ...             ...  ...            ...            ...                  ...
# 18534           CAM   21            174             68         Sligo Rovers
# 18535           CDM   17            175             60         Guangzhou FC
# 18536            RM   18            170             65           Derry City
# 18537            CB   17            178             65           Derry City
# 18538            LB   25            176             66  NorthEast United FC
#
#        ...  RM Rating  LWB Rating CDM Rating RWB Rating  LB Rating CB Rating  \
# 0      ...         91          67         66         67         62        53
# 1      ...         89          67         67         67         63        58
# 2      ...         86          67         69         67         64        63
# 3      ...         91          82         82         82         78        72
# 4      ...         92          70         66         70         66        57
# ...    ...        ...         ...        ...        ...        ...       ...
# 18534  ...         50          41         38         41         40        36
# 18535  ...         45          47         48         47         49        49
# 18536  ...         52          46         44         46         46        42
# 18537  ...         33          44         42         44         47        49
# 18538  ...         44          46         43         46         47        47
#
#       RB Rating  GK Rating          Nationality  Gap_Potential
# 0            62         22            Argentina              0
# 1            63         21               France              0
# 2            64         22               Poland              0
# 3            78         24              Belgium              0
# 4            66         21               France              4
# ...         ...        ...                  ...            ...
# 18534        40         15  Republic of Ireland              9
# 18535        49         15             China PR             10
# 18536        46         17     Northern Ireland             20
# 18537        47         15  Republic of Ireland             14
# 18538        47         19                India              3
#
# [18539 rows x 36 columns]

# %%
#Get the data of all the players at Manchester City to have an overview of the players scores and potentials.

Fifa_MC = Fifa_Cle.loc[Fifa_Cle['Club Name'] == "Manchester City"]
Fifa_MC
# Out:
#                 Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 3           K. De Bruyne       91         91       107500000           CM,CAM
# 16               Ederson       89         91        88000000               GK
# 20            Rúben Dias       88         91       107500000               CB
# 21            E. Haaland       88         94       148000000               ST
# 23        Bernardo Silva       88         88        97500000           CAM,CM
# 24          João Cancelo       88         88        82500000            LB,RB
# 31                 Rodri       87         89        88500000              CDM
# 48             R. Mahrez       86         86        56500000            RW,RM
# 55            A. Laporte       86         87        64500000               CB
# 68           İ. Gündoğan       85         85        44000000           CM,CDM
# 69             K. Walker       85         85        37500000               RB
# 83              P. Foden       85         92       109500000        LW,CF,CAM
# 103          J. Grealish       84         84        46000000        LW,LM,CAM
# 194            J. Stones       83         84        34500000               CB
# 320            M. Akanji       81         82        26500000               CB
# 361          K. Phillips       81         85        32000000           CDM,CM
# 430            S. Ortega       80         80        14500000               GK
# 680           J. Álvarez       78         86        32000000         ST,RW,LW
# 759               N. Aké       78         80        15000000            CB,LB
# 1972        Sergio Gómez       74         83         9000000         LB,RM,LM
# 8072           C. Palmer       67         85         2700000        RW,CAM,CF
# 9267           M. Rogers       66         82         2200000            LW,RW
# 10444          S. Carson       65         65           80000               GK
# 14529           R. Lewis       61         82         1000000               RB
# 15117          B. Knight       60         74          600000               RW
# 16308       A. Robertson       58         78          575000               CM
# 16314  J. Wilson-Esbrand       58         76          500000               LB
#
#       Best Position  Age  Height(in cm)  Weight(in kg)        Club Name  ...  \
# 3                CM   31            181             70  Manchester City  ...
# 16               GK   28            188             86  Manchester City  ...
# 20               CB   25            187             82  Manchester City  ...
# 21               ST   21            195             94  Manchester City  ...
# 23              CAM   27            173             64  Manchester City  ...
# 24               LB   28            182             74  Manchester City  ...
# 31              CDM   26            191             82  Manchester City  ...
# 48               RW   31            179             67  Manchester City  ...
# 55               CB   28            191             85  Manchester City  ...
# 68               CM   31            180             80  Manchester City  ...
# 69               RB   32            183             83  Manchester City  ...
# 83              CAM   22            171             69  Manchester City  ...
# 103              LW   26            180             81  Manchester City  ...
# 194              CB   28            188             76  Manchester City  ...
# 320              CB   26            187             91  Manchester City  ...
# 361             CDM   26            178             72  Manchester City  ...
# 430              GK   29            185             88  Manchester City  ...
# 680             CAM   22            173             71  Manchester City  ...
# 759              CB   27            180             75  Manchester City  ...
# 1972            CAM   21            171             68  Manchester City  ...
# 8072            CAM   20            189             74  Manchester City  ...
# 9267             RM   19            187             80  Manchester City  ...
# 10444            GK   36            190             86  Manchester City  ...
# 14529            RB   17            175             70  Manchester City  ...
# 15117           CAM   20            170             59  Manchester City  ...
# 16308           CAM   19            180             66  Manchester City  ...
# 16314            LB   19            176             65  Manchester City  ...
#
#        RM Rating  LWB Rating CDM Rating RWB Rating  LB Rating CB Rating  \
# 3             91          82         82         82         78        72
# 16            47          40         47         40         39        38
# 20            67          81         86         81         83        90
# 21            80          65         67         65         64        65
# 23            88          79         77         79         75        67
# 24            88          88         86         88         87        82
# 31            79          82         87         82         82        85
# 48            86          67         64         67         62        52
# 55            70          80         85         80         81        87
# 68            85          80         83         80         78        75
# 69            81          85         84         85         85        84
# 83            87          75         74         75         72        62
# 103           84          71         70         71         66        57
# 194           73          80         83         80         81        84
# 320           70          78         82         78         80        82
# 361           76          80         82         80         79        81
# 430           39          35         40         35         34        35
# 680           81          69         69         69         67        64
# 759           71          78         79         78         79        80
# 1972          75          75         74         75         74        69
# 8072          68          59         57         59         57        52
# 9267          67          57         54         57         55        50
# 10444         27          26         27         26         26        29
# 14529         55          60         54         60         61        59
# 15117         60          47         43         47         44        38
# 16308         61          57         58         57         57        55
# 16314         56          58         53         58         58        56
#
#       RB Rating  GK Rating  Nationality  Gap_Potential
# 3            78         24      Belgium              0
# 16           39         90       Brazil              2
# 20           83         21     Portugal              3
# 21           64         22       Norway              6
# 23           75         21     Portugal              0
# 24           87         22     Portugal              0
# 31           82         21        Spain              2
# 48           62         21      Algeria              0
# 55           81         21        Spain              1
# 68           78         22      Germany              0
# 69           85         22      England              0
# 83           72         22      England              7
# 103          66         21      England              0
# 194          81         20      England              1
# 320          80         19  Switzerland              1
# 361          79         20      England              4
# 430          34         80      Germany              0
# 680          67         19    Argentina              8
# 759          79         21  Netherlands              2
# 1972         74         19        Spain              9
# 8072         57         17      England             18
# 9267         55         18      England             16
# 10444        26         65      England              0
# 14529        61         19      England             21
# 15117        44         16      England             14
# 16308        57         16      England             20
# 16314        58         16      England             18
#
# [27 rows x 36 columns]

# %%
# Get the data of all the players outside of Manchester City.

Fifa_Other = Fifa_Cle.loc[Fifa_Cle['Club Name'] != "Manchester City"]
Fifa_Other
# Out:
#              Known As  Overall  Potential  Value(in Euro) Positions Played  \
# 0            L. Messi       91         91        54000000               RW
# 1          K. Benzema       91         91        64000000            CF,ST
# 2      R. Lewandowski       91         91        84000000               ST
# 4           K. Mbappé       91         95       190500000            ST,LW
# 5            M. Salah       90         90       115500000               RW
# ...               ...      ...        ...             ...              ...
# 18534      D. Collins       47         56          110000            ST,RM
# 18535    Yang Dejiang       47         57           90000              CDM
# 18536       L. Mullan       47         67          130000               CM
# 18537    D. McCallion       47         61          100000               CB
# 18538        N. Rabha       47         50           60000               LB
#
#       Best Position  Age  Height(in cm)  Weight(in kg)            Club Name  \
# 0               CAM   35            169             67  Paris Saint-Germain
# 1                CF   34            185             81       Real Madrid CF
# 2                ST   33            185             81         FC Barcelona
# 4                ST   23            182             73  Paris Saint-Germain
# 5                RW   30            175             71            Liverpool
# ...             ...  ...            ...            ...                  ...
# 18534           CAM   21            174             68         Sligo Rovers
# 18535           CDM   17            175             60         Guangzhou FC
# 18536            RM   18            170             65           Derry City
# 18537            CB   17            178             65           Derry City
# 18538            LB   25            176             66  NorthEast United FC
#
#        ...  RM Rating  LWB Rating CDM Rating RWB Rating  LB Rating CB Rating  \
# 0      ...         91          67         66         67         62        53
# 1      ...         89          67         67         67         63        58
# 2      ...         86          67         69         67         64        63
# 4      ...         92          70         66         70         66        57
# 5      ...         90          74         71         74         70        61
# ...    ...        ...         ...        ...        ...        ...       ...
# 18534  ...         50          41         38         41         40        36
# 18535  ...         45          47         48         47         49        49
# 18536  ...         52          46         44         46         46        42
# 18537  ...         33          44         42         44         47        49
# 18538  ...         44          46         43         46         47        47
#
#       RB Rating  GK Rating          Nationality  Gap_Potential
# 0            62         22            Argentina              0
# 1            63         21               France              0
# 2            64         22               Poland              0
# 4            66         21               France              4
# 5            70         25                Egypt              0
# ...         ...        ...                  ...            ...
# 18534        40         15  Republic of Ireland              9
# 18535        49         15             China PR             10
# 18536        46         17     Northern Ireland             20
# 18537        47         15  Republic of Ireland             14
# 18538        47         19                India              3
#
# [18512 rows x 36 columns]

# %%
#ANALYSIS

# %%
# Create a new DataFrame to focus on the ratings of all the players (in and out of MC)

Fifa_Other.columns
# Out:
# Index(['Known As', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Age', 'Height(in cm)',
#        'Weight(in kg)', 'Club Name', 'Wage(in Euro)', 'Release Clause',
#        'Club Position', 'Contract Until', 'Joined On', 'On Loan',
#        'National Team Name', 'ST Rating', 'LW Rating', 'LF Rating',
#        'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
#        'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
#        'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
#        'Gap_Potential'],
#       dtype='object')

# %%
Fifa_MP = Fifa_Cle[['Known As', 'Overall', 'Potential','Positions Played','Club Name',
       'Club Position', 'ST Rating', 'LW Rating', 'LF Rating',
       'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
       'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
       'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
       'Gap_Potential']]

# %%
Fifa_MP
# Out:
#              Known As  Overall  Potential Positions Played  \
# 0            L. Messi       91         91               RW
# 1          K. Benzema       91         91            CF,ST
# 2      R. Lewandowski       91         91               ST
# 3        K. De Bruyne       91         91           CM,CAM
# 4           K. Mbappé       91         95            ST,LW
# ...               ...      ...        ...              ...
# 18534      D. Collins       47         56            ST,RM
# 18535    Yang Dejiang       47         57              CDM
# 18536       L. Mullan       47         67               CM
# 18537    D. McCallion       47         61               CB
# 18538        N. Rabha       47         50               LB
#
#                  Club Name Club Position  ST Rating  LW Rating  LF Rating  \
# 0      Paris Saint-Germain            RW         90         90         91
# 1           Real Madrid CF            CF         91         87         89
# 2             FC Barcelona            ST         91         85         88
# 3          Manchester City            CM         86         88         87
# 4      Paris Saint-Germain            ST         92         90         90
# ...                    ...           ...        ...        ...        ...
# 18534         Sligo Rovers           RES         49         50         50
# 18535         Guangzhou FC           SUB         44         43         43
# 18536           Derry City           SUB         48         49         49
# 18537           Derry City           SUB         33         30         30
# 18538  NorthEast United FC           RES         41         42         40
#
#        CF Rating  ...  RM Rating  LWB Rating  CDM Rating  RWB Rating  \
# 0             91  ...         91          67          66          67
# 1             89  ...         89          67          67          67
# 2             88  ...         86          67          69          67
# 3             87  ...         91          82          82          82
# 4             90  ...         92          70          66          70
# ...          ...  ...        ...         ...         ...         ...
# 18534         50  ...         50          41          38          41
# 18535         43  ...         45          47          48          47
# 18536         49  ...         52          46          44          46
# 18537         30  ...         33          44          42          44
# 18538         40  ...         44          46          43          46
#
#        LB Rating  CB Rating  RB Rating  GK Rating          Nationality  \
# 0             62         53         62         22            Argentina
# 1             63         58         63         21               France
# 2             64         63         64         22               Poland
# 3             78         72         78         24              Belgium
# 4             66         57         66         21               France
# ...          ...        ...        ...        ...                  ...
# 18534         40         36         40         15  Republic of Ireland
# 18535         49         49         49         15             China PR
# 18536         46         42         46         17     Northern Ireland
# 18537         47         49         47         15  Republic of Ireland
# 18538         47         47         47         19                India
#
#        Gap_Potential
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  4
# ...              ...
# 18534              9
# 18535             10
# 18536             20
# 18537             14
# 18538              3
#
# [18539 rows x 25 columns]

# %%
Fifa_MP.groupby(['Positions Played']).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# --> 959 return cy_op.cython_operation(
#     960     values=values,
#     961     axis=axis,
#     962     min_count=min_count,
#     963     comp_ids=ids,
#     964     ngroups=ngroups,
#     965     **kwargs,
#     966 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:657, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     649     return self._ea_wrap_cython_operation(
#     650         values,
#     651         min_count=min_count,
#    (...)
#     654         **kwargs,
#     655     )
# --> 657 return self._cython_op_ndim_compat(
#     658     values,
#     659     min_count=min_count,
#     660     ngroups=ngroups,
#     661     comp_ids=comp_ids,
#     662     mask=None,
#     663     **kwargs,
#     664 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:497, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     495     return res.T
# --> 497 return self._call_cython_op(
#     498     values,
#     499     min_count=min_count,
#     500     ngroups=ngroups,
#     501     comp_ids=comp_ids,
#     502     mask=mask,
#     503     result_mask=result_mask,
#     504     **kwargs,
#     505 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:541, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540 out_shape = self._get_output_shape(ngroups, values)
# --> 541 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542 values = self._get_cython_vals(values)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:173, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     171 if "object" not in f.__signatures__:
#     172     # raise NotImplementedError here rather than TypeError later
# --> 173     raise NotImplementedError(
#     174         f"function is not implemented for this dtype: "
#     175         f"[how->{how},dtype->{dtype_str}]"
#     176     )
#     177 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: "N. FekirL. StindlÓ. TrejoN. LodeiroL. ZelarayánJ. LingardBrahimAdilson EdradaL. AcostaG. KakutaR. CabellaJ. BerthomierJ. CazaresB. RamselaarM. MancosuA. DiamantiG. PereiroE. VignatoAlam BasteirinhoR. SchmidM. DæhliCaio MilaçarJoão AmaralDeiverson KaioMauro RiboasI. ChairA. MarchesanoH. BoumousTiago PombeiraA. PritchardS. ThillMarlion RolimLuildo SimõesJoão CarvalhoM. NinkovićSandro MaceiraJ. BrimmerCrivellaroPaulo DaineiroM. CovaR. ArdilesDani RamírezH. SudakovDavide EustáquioH. HaraldssonMarco TúlioJorgino BaumerClaudio MouriaYan SasseB. KraevV. BichakhchyanE. RrocaL. NietoEstevãtinhoN. SkyttäA. FeratiD. HorganM. AklioucheS. CampoC. ValenzuelaH. DomingoA. FontanaWelliton HelmesM. El ArouchD. DouéD. KameriJ. CruzA. RoguljićMiguel SousaS. MkhuliseM. JayM. ZemzemiC. VillanuevaD. MaldiniS. MbuleR. CorluI. Suero FernándezL. TomlinH. ChapmanM. MonsalveT. AasgaardC. VolpatoD. LunaN. MostiO. WählingC. HarenbrockA. TsarenkoJ. McAteeC. NoßA. AlvaradoF. Palacios MartínezL. D'AndreaJ. CaicedoAndré RicardoB. VaštšukB. OrtegaM. ChamDiogo PintoL. StankovskiC. Lemonheigh-EvansB. InceP. AaronsonJosi MouraldoA. ŁyszczarzT. BischofJ. McAteeO. OcheretkoDaliL. HarrisT. NakaiJ. WaiteE. KrasniqiM. ShabaniM. DamarR. SchneiderL. GonzálezF. ClarkeB. OldK. ParraJ. BahoyaO. RossR. TierneyJ. SeoHwang Jae HwanA. AydınD. TrejoT. SuengchitthawonA. DemirelY. BellacheM. ArslanC. NegeleDiego GustavoK. ŠekularacG. OlzerF. PollockL. ValenteW. ŁaskiB. KneževićDani GonzálezG. AcostaJ. BookjansK. WiethaupR. HughesZ. ObieroA. SobońC. PeupionH. AnhariE. AdamsM. BurmanT. OumaJ. SilvaG. HallS. WikmanD. BunkE. McLaughlinD. G'BeulyC. CongreveR. MaherÁ. NistorD. KacuriK. JelacicI. StrzałekM. DouaneJ. MullinsL. KåhedS. El KhiarN. MilanovicI. CissokhoM. NemilD. LobbanJ. YullB. LloydK. FotheringhamB. Al HurayjiN. Al RashoudiR. DuncanN. Al SaadiC. McLaughlinC. AlbuH. SofianuD. LipsiucK. EvansE. AlagichO. LeśniakD. LyngdohJ. Ferizaj"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 Fifa_MP.groupby(['Positions Played']).mean()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1855, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
# -> 1855     result = self._cython_agg_general(
#    1856         "mean",
#    1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1503, in BlockManager.grouped_reduce(self, func)
#    1499 if blk.is_object:
#    1500     # split on object-dtype blocks bc some columns may raise
#    1501     #  while others do not.
#    1502     for sb in blk._split():
# -> 1503         applied = sb.apply(func)
#    1504         result_blocks = extend_blocks(applied, result_blocks)
#    1505 else:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:329, in Block.apply(self, func, **kwargs)
#     323 @final
#     324 def apply(self, func, **kwargs) -> list[Block]:
#     325     """
#     326     apply the function to my values; return a block if we are not
#     327     one
#     328     """
# --> 329     result = func(self.values, **kwargs)
#     331     return self._split_op_result(result)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1503, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    (...)
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
# -> 1503     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1457, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1452     ser = df.iloc[:, 0]
#    1454 # We do not get here with UDFs, so we know that our dtype
#    1455 #  should always be preserved by the implemented aggregations
#    1456 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1459 if isinstance(values, Categorical):
#    1460     # Because we only get here with known dtype-preserving
#    1461     #  reductions, we cast back to Categorical.
#    1462     # TODO: if we ever get "rank" working, exclude it here.
#    1463     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:994, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     987 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     988     # we can preserve a little bit more aggressively with EA dtype
#     989     #  because maybe_cast_pointwise_result will do a try/except
#     990     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     991     #  is sufficiently strict that it casts appropriately.
#     992     preserve_dtype = True
# --> 994 result = self._aggregate_series_pure_python(obj, func)
#     996 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     997 if preserve_dtype:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1015, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1012 splitter = self._get_splitter(obj, axis=0)
#    1014 for i, group in enumerate(splitter):
# -> 1015     res = func(group)
#    1016     res = libreduction.extract_result(res)
#    1018     if not initialized:
#    1019         # We only do this validation on the first iteration
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1857, in GroupBy.mean.<locals>.<lambda>(x)
#    1853     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854 else:
#    1855     result = self._cython_agg_general(
#    1856         "mean",
# -> 1857         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858         numeric_only=numeric_only,
#    1859     )
#    1860     return result.__finalize__(self.obj, method="groupby")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert N. FekirL. StindlÓ. TrejoN. LodeiroL. ZelarayánJ. LingardBrahimAdilson EdradaL. AcostaG. KakutaR. CabellaJ. BerthomierJ. CazaresB. RamselaarM. MancosuA. DiamantiG. PereiroE. VignatoAlam BasteirinhoR. SchmidM. DæhliCaio MilaçarJoão AmaralDeiverson KaioMauro RiboasI. ChairA. MarchesanoH. BoumousTiago PombeiraA. PritchardS. ThillMarlion RolimLuildo SimõesJoão CarvalhoM. NinkovićSandro MaceiraJ. BrimmerCrivellaroPaulo DaineiroM. CovaR. ArdilesDani RamírezH. SudakovDavide EustáquioH. HaraldssonMarco TúlioJorgino BaumerClaudio MouriaYan SasseB. KraevV. BichakhchyanE. RrocaL. NietoEstevãtinhoN. SkyttäA. FeratiD. HorganM. AklioucheS. CampoC. ValenzuelaH. DomingoA. FontanaWelliton HelmesM. El ArouchD. DouéD. KameriJ. CruzA. RoguljićMiguel SousaS. MkhuliseM. JayM. ZemzemiC. VillanuevaD. MaldiniS. MbuleR. CorluI. Suero FernándezL. TomlinH. ChapmanM. MonsalveT. AasgaardC. VolpatoD. LunaN. MostiO. WählingC. HarenbrockA. TsarenkoJ. McAteeC. NoßA. AlvaradoF. Palacios MartínezL. D'AndreaJ. CaicedoAndré RicardoB. VaštšukB. OrtegaM. ChamDiogo PintoL. StankovskiC. Lemonheigh-EvansB. InceP. AaronsonJosi MouraldoA. ŁyszczarzT. BischofJ. McAteeO. OcheretkoDaliL. HarrisT. NakaiJ. WaiteE. KrasniqiM. ShabaniM. DamarR. SchneiderL. GonzálezF. ClarkeB. OldK. ParraJ. BahoyaO. RossR. TierneyJ. SeoHwang Jae HwanA. AydınD. TrejoT. SuengchitthawonA. DemirelY. BellacheM. ArslanC. NegeleDiego GustavoK. ŠekularacG. OlzerF. PollockL. ValenteW. ŁaskiB. KneževićDani GonzálezG. AcostaJ. BookjansK. WiethaupR. HughesZ. ObieroA. SobońC. PeupionH. AnhariE. AdamsM. BurmanT. OumaJ. SilvaG. HallS. WikmanD. BunkE. McLaughlinD. G'BeulyC. CongreveR. MaherÁ. NistorD. KacuriK. JelacicI. StrzałekM. DouaneJ. MullinsL. KåhedS. El KhiarN. MilanovicI. CissokhoM. NemilD. LobbanJ. YullB. LloydK. FotheringhamB. Al HurayjiN. Al RashoudiR. DuncanN. Al SaadiC. McLaughlinC. AlbuH. SofianuD. LipsiucK. EvansE. AlagichO. LeśniakD. LyngdohJ. Ferizaj to numeric

# %%
Fifa_MP["Overall_Mean"] = Fifa_MP.groupby(['Club Position']).agg({"Overall":"mean"})
Fifa_MP
# Out:
# C:\Users\withl\AppData\Local\Temp\ipykernel_18512\2664732078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_MP["Overall_Mean"] = Fifa_MP.groupby(['Club Position']).agg({"Overall":"mean"})
#              Known As  Overall  Potential Positions Played  \
# 0            L. Messi       91         91               RW
# 1          K. Benzema       91         91            CF,ST
# 2      R. Lewandowski       91         91               ST
# 3        K. De Bruyne       91         91           CM,CAM
# 4           K. Mbappé       91         95            ST,LW
# ...               ...      ...        ...              ...
# 18534      D. Collins       47         56            ST,RM
# 18535    Yang Dejiang       47         57              CDM
# 18536       L. Mullan       47         67               CM
# 18537    D. McCallion       47         61               CB
# 18538        N. Rabha       47         50               LB
#
#                  Club Name Club Position  ST Rating  LW Rating  LF Rating  \
# 0      Paris Saint-Germain            RW         90         90         91
# 1           Real Madrid CF            CF         91         87         89
# 2             FC Barcelona            ST         91         85         88
# 3          Manchester City            CM         86         88         87
# 4      Paris Saint-Germain            ST         92         90         90
# ...                    ...           ...        ...        ...        ...
# 18534         Sligo Rovers           RES         49         50         50
# 18535         Guangzhou FC           SUB         44         43         43
# 18536           Derry City           SUB         48         49         49
# 18537           Derry City           SUB         33         30         30
# 18538  NorthEast United FC           RES         41         42         40
#
#        CF Rating  ...  LWB Rating  CDM Rating  RWB Rating  LB Rating  \
# 0             91  ...          67          66          67         62
# 1             89  ...          67          67          67         63
# 2             88  ...          67          69          67         64
# 3             87  ...          82          82          82         78
# 4             90  ...          70          66          70         66
# ...          ...  ...         ...         ...         ...        ...
# 18534         50  ...          41          38          41         40
# 18535         43  ...          47          48          47         49
# 18536         49  ...          46          44          46         46
# 18537         30  ...          44          42          44         47
# 18538         40  ...          46          43          46         47
#
#        CB Rating  RB Rating  GK Rating          Nationality  Gap_Potential  \
# 0             53         62         22            Argentina              0
# 1             58         63         21               France              0
# 2             63         64         22               Poland              0
# 3             72         78         24              Belgium              0
# 4             57         66         21               France              4
# ...          ...        ...        ...                  ...            ...
# 18534         36         40         15  Republic of Ireland              9
# 18535         49         49         15             China PR             10
# 18536         42         46         17     Northern Ireland             20
# 18537         49         47         15  Republic of Ireland             14
# 18538         47         47         19                India              3
#
#        Overall_Mean
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 18534           NaN
# 18535           NaN
# 18536           NaN
# 18537           NaN
# 18538           NaN
#
# [18539 rows x 26 columns]

# %%
Fifa_MP.groupby(['Positions Played']).mean()

# %%
position_counts = Fifa_MP['Positions Played'].value_counts()
display(position_counts)
# Out:
# Positions Played
# CB            2433
# GK            2061
# ST            1719
# CDM,CM         953
# CM             732
#               ...
# LM,CF,ST         1
# CAM,CM,LWB       1
# LB,LM,RB         1
# CM,RW,CDM        1
# CM,CF,CDM        1
# Name: count, Length: 693, dtype: int64

# %%
#Calculate the mean values for each position:
position_means = Fifa_MP.groupby(['Positions Played'])['Overall'].mean().reset_index()

#Rename the "Overall" column with the position_means DataFrame to "Mean Overall".
position_means.rename(columns={'Overall': 'Mean Overall'}, inplace=True)

#Merge the mean values back into your initial DataFrame based on the "Club Position" column:
Fifa_MP = Fifa_MP.merge(position_means, on='Positions Played', how='left')

Fifa_MP
# Out:
#              Known As  Overall  Potential Positions Played  \
# 0            L. Messi       91         91               RW
# 1          K. Benzema       91         91            CF,ST
# 2      R. Lewandowski       91         91               ST
# 3        K. De Bruyne       91         91           CM,CAM
# 4           K. Mbappé       91         95            ST,LW
# ...               ...      ...        ...              ...
# 18534      D. Collins       47         56            ST,RM
# 18535    Yang Dejiang       47         57              CDM
# 18536       L. Mullan       47         67               CM
# 18537    D. McCallion       47         61               CB
# 18538        N. Rabha       47         50               LB
#
#                  Club Name Club Position  ST Rating  LW Rating  LF Rating  \
# 0      Paris Saint-Germain            RW         90         90         91
# 1           Real Madrid CF            CF         91         87         89
# 2             FC Barcelona            ST         91         85         88
# 3          Manchester City            CM         86         88         87
# 4      Paris Saint-Germain            ST         92         90         90
# ...                    ...           ...        ...        ...        ...
# 18534         Sligo Rovers           RES         49         50         50
# 18535         Guangzhou FC           SUB         44         43         43
# 18536           Derry City           SUB         48         49         49
# 18537           Derry City           SUB         33         30         30
# 18538  NorthEast United FC           RES         41         42         40
#
#        CF Rating  ...  LB Rating  CB Rating  RB Rating  GK Rating  \
# 0             91  ...         62         53         62         22
# 1             89  ...         63         58         63         21
# 2             88  ...         64         63         64         22
# 3             87  ...         78         72         78         24
# 4             90  ...         66         57         66         21
# ...          ...  ...        ...        ...        ...        ...
# 18534         50  ...         40         36         40         15
# 18535         43  ...         49         49         49         15
# 18536         49  ...         46         42         46         17
# 18537         30  ...         47         49         47         15
# 18538         40  ...         47         47         47         19
#
#                Nationality  Gap_Potential  Overall_Mean  Mean Overall_x  \
# 0                Argentina              0           NaN       65.040816
# 1                   France              0           NaN       71.095238
# 2                   Poland              0           NaN       65.657941
# 3                  Belgium              0           NaN       66.021186
# 4                   France              4           NaN       65.962121
# ...                    ...            ...           ...             ...
# 18534  Republic of Ireland              9           NaN       65.237500
# 18535             China PR             10           NaN       63.166023
# 18536     Northern Ireland             20           NaN       62.662568
# 18537  Republic of Ireland             14           NaN       66.445540
# 18538                India              3           NaN       65.231660
#
#        Mean Overall_y  Mean Overall
# 0           65.040816     65.040816
# 1           71.095238     71.095238
# 2           65.657941     65.657941
# 3           66.021186     66.021186
# 4           65.962121     65.962121
# ...               ...           ...
# 18534       65.237500     65.237500
# 18535       63.166023     63.166023
# 18536       62.662568     62.662568
# 18537       66.445540     66.445540
# 18538       65.231660     65.231660
#
# [18539 rows x 29 columns]

# %%
#Re-order the columns to have "Overall" next to "Mean Overall"

Fifa_MP = Fifa_MP[['Known As','Overall', 'Mean Overall','Potential','Positions Played','Club Position', 'Club Name', 'ST Rating',
       'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
       'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
       'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
       'GK Rating', 'Nationality', 'Gap_Potential']]

Fifa_MP
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 #Re-order the columns to have "Overall" next to "Mean Overall"
# ----> 3 Fifa_MP = Fifa_MP[['Known As','Overall', 'Mean Overall','Potential','Positions Played','Club Position', 'Club Name', 'ST Rating',
#       4        'LW Rating', 'LF Rating', 'CF Rating', 'RF Rating', 'RW Rating',
#       5        'CAM Rating', 'LM Rating', 'CM Rating', 'RM Rating', 'LWB Rating',
#       6        'CDM Rating', 'RWB Rating', 'LB Rating', 'CB Rating', 'RB Rating',
#       7        'GK Rating', 'Nationality', 'Gap_Potential']]
#       9 Fifa_MP
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Mean Overall'] not in index"

# %%
Fifa_MC = Fifa_MP.loc[Fifa_MP['Club Name'] == "Manchester City"]
Fifa_MC
# Out:
#                 Known As  Overall  Mean Overall  Potential Positions Played  \
# 3           K. De Bruyne       91     66.021186         91           CM,CAM
# 16               Ederson       89     64.453178         91               GK
# 20            Rúben Dias       88     66.445540         91               CB
# 21            E. Haaland       88     65.657941         94               ST
# 23        Bernardo Silva       88     66.387597         88           CAM,CM
# 24          João Cancelo       88     65.800000         88            LB,RB
# 31                 Rodri       87     63.166023         89              CDM
# 48             R. Mahrez       86     69.339623         86            RW,RM
# 55            A. Laporte       86     66.445540         87               CB
# 68           İ. Gündoğan       85     67.120235         85           CM,CDM
# 69             K. Walker       85     65.377871         85               RB
# 83              P. Foden       85     77.500000         92        LW,CF,CAM
# 103          J. Grealish       84     69.250000         84        LW,LM,CAM
# 194            J. Stones       83     66.445540         84               CB
# 320            M. Akanji       81     66.445540         82               CB
# 361          K. Phillips       81     67.414481         85           CDM,CM
# 430            S. Ortega       80     64.453178         80               GK
# 680           J. Álvarez       78     64.615385         86         ST,RW,LW
# 759               N. Aké       78     66.200000         80            CB,LB
# 1972        Sergio Gómez       74     69.500000         83         LB,RM,LM
# 8072           C. Palmer       67     67.000000         85        RW,CAM,CF
# 9267           M. Rogers       66     66.170000         82            LW,RW
# 10444          S. Carson       65     64.453178         65               GK
# 14529           R. Lewis       61     65.377871         82               RB
# 15117          B. Knight       60     65.040816         74               RW
# 16308       A. Robertson       58     62.662568         78               CM
# 16314  J. Wilson-Esbrand       58     65.231660         76               LB
#
#       Club Position        Club Name  ST Rating  LW Rating  LF Rating  ...  \
# 3                CM  Manchester City         86         88         87  ...
# 16               GK  Manchester City         43         41         43  ...
# 20               CB  Manchester City         64         59         60  ...
# 21               ST  Manchester City         90         80         84  ...
# 23               RW  Manchester City         80         86         84  ...
# 24               LB  Manchester City         81         84         83  ...
# 31              CDM  Manchester City         79         74         77  ...
# 48              SUB  Manchester City         83         85         85  ...
# 55               CB  Manchester City         69         64         66  ...
# 68               CM  Manchester City         81         82         82  ...
# 69               RB  Manchester City         77         76         76  ...
# 83               LW  Manchester City         80         84         83  ...
# 103             SUB  Manchester City         78         83         81  ...
# 194             SUB  Manchester City         69         69         69  ...
# 320             SUB  Manchester City         66         65         65  ...
# 361             SUB  Manchester City         72         72         72  ...
# 430             SUB  Manchester City         37         34         37  ...
# 680             SUB  Manchester City         80         80         80  ...
# 759             SUB  Manchester City         68         67         66  ...
# 1972            SUB  Manchester City         70         73         72  ...
# 8072            SUB  Manchester City         65         67         66  ...
# 9267            RES  Manchester City         66         66         65  ...
# 10444           SUB  Manchester City         30         25         27  ...
# 14529           SUB  Manchester City         50         53         50  ...
# 15117           RES  Manchester City         58         60         59  ...
# 16308           RES  Manchester City         58         57         58  ...
# 16314           RES  Manchester City         49         53         50  ...
#
#        RM Rating  LWB Rating  CDM Rating  RWB Rating  LB Rating  CB Rating  \
# 3             91          82          82          82         78         72
# 16            47          40          47          40         39         38
# 20            67          81          86          81         83         90
# 21            80          65          67          65         64         65
# 23            88          79          77          79         75         67
# 24            88          88          86          88         87         82
# 31            79          82          87          82         82         85
# 48            86          67          64          67         62         52
# 55            70          80          85          80         81         87
# 68            85          80          83          80         78         75
# 69            81          85          84          85         85         84
# 83            87          75          74          75         72         62
# 103           84          71          70          71         66         57
# 194           73          80          83          80         81         84
# 320           70          78          82          78         80         82
# 361           76          80          82          80         79         81
# 430           39          35          40          35         34         35
# 680           81          69          69          69         67         64
# 759           71          78          79          78         79         80
# 1972          75          75          74          75         74         69
# 8072          68          59          57          59         57         52
# 9267          67          57          54          57         55         50
# 10444         27          26          27          26         26         29
# 14529         55          60          54          60         61         59
# 15117         60          47          43          47         44         38
# 16308         61          57          58          57         57         55
# 16314         56          58          53          58         58         56
#
#        RB Rating  GK Rating  Nationality  Gap_Potential
# 3             78         24      Belgium              0
# 16            39         90       Brazil              2
# 20            83         21     Portugal              3
# 21            64         22       Norway              6
# 23            75         21     Portugal              0
# 24            87         22     Portugal              0
# 31            82         21        Spain              2
# 48            62         21      Algeria              0
# 55            81         21        Spain              1
# 68            78         22      Germany              0
# 69            85         22      England              0
# 83            72         22      England              7
# 103           66         21      England              0
# 194           81         20      England              1
# 320           80         19  Switzerland              1
# 361           79         20      England              4
# 430           34         80      Germany              0
# 680           67         19    Argentina              8
# 759           79         21  Netherlands              2
# 1972          74         19        Spain              9
# 8072          57         17      England             18
# 9267          55         18      England             16
# 10444         26         65      England              0
# 14529         61         19      England             21
# 15117         44         16      England             14
# 16308         57         16      England             20
# 16314         58         16      England             18
#
# [27 rows x 26 columns]

# %%
"""This is where we realized that we only have substitutes and reserve club positions players with an overall score below the mean score of all the other players.
We took the decision to instead take the mean of the Top 10 champions league teams of 2023-2024 which are the following:

1. Manchester City
2. Real Madrid
3. FC Barcelona
4. Bayern Munich
5. Inter
6. Real Sociedad
7. Arsenal
8. PSG
9. Atletico de Madrid
10. Porto

"""

# %%
Fifa_Champions = Fifa[Fifa['Club Name'].isin(["Manchester City", "Real Madrid", "FC Barcelona","Bayern Munich","Inter","Real Sociedad", "Arsenal","Paris Saint-Germain", "Atletico de Madrid","Porto"])]

Fifa_Champions
# Out:
#                 Known As                   Full Name  Overall  Potential  \
# 0               L. Messi                Lionel Messi       91         91
# 2         R. Lewandowski          Robert Lewandowski       91         91
# 3           K. De Bruyne             Kevin De Bruyne       91         91
# 4              K. Mbappé               Kylian Mbappé       91         95
# 11             Neymar Jr  Neymar da Silva Santos Jr.       89         89
# ...                  ...                         ...      ...        ...
# 15117          B. Knight                  Ben Knight       60         74
# 15912  A. Cozier-Duberry       Amario Cozier-Duberry       59         78
# 16308       A. Robertson              Alex Robertson       58         78
# 16314  J. Wilson-Esbrand       Joshua Wilson-Esbrand       58         76
# 16986           L. Sousa                  Lino Sousa       56         80
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# 0            54000000               RW           CAM   Argentina
# 2            84000000               ST            ST      Poland
# 3           107500000           CM,CAM            CM     Belgium
# 4           190500000            ST,LW            ST      France
# 11           99500000               LW            LW      Brazil
# ...               ...              ...           ...         ...
# 15117          600000               RW           CAM     England
# 15912          550000           LM,CAM            LM     England
# 16308          575000               CM           CAM     England
# 16314          500000               LB            LB     England
# 16986          425000               LB            LB     England
#
#                                              Image Link  Age  ...  LM Rating  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         86
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         92
# 11     https://cdn.sofifa.net/players/190/871/23_60.png   30  ...         89
# ...                                                 ...  ...  ...        ...
# 15117  https://cdn.sofifa.net/players/263/955/23_60.png   20  ...         60
# 15912  https://cdn.sofifa.net/players/271/743/23_60.png   17  ...         60
# 16308  https://cdn.sofifa.net/players/259/677/23_60.png   19  ...         61
# 16314  https://cdn.sofifa.net/players/264/681/23_60.png   19  ...         56
# 16986  https://cdn.sofifa.net/players/271/808/23_60.png   17  ...         52
#
#        CM Rating  RM Rating  LWB Rating CDM Rating  RWB Rating  LB Rating  \
# 0             88         91          67         66          67         62
# 2             83         86          67         69          67         64
# 3             91         91          82         82          82         78
# 4             84         92          70         66          70         66
# 11            85         89          69         66          69         64
# ...          ...        ...         ...        ...         ...        ...
# 15117         53         60          47         43          47         44
# 15912         53         60          48         44          48         45
# 16308         60         61          57         58          57         57
# 16314         50         56          58         53          58         58
# 16986         48         52          56         52          56         56
#
#       CB Rating RB Rating GK Rating
# 0            53        62        22
# 2            63        64        22
# 3            72        78        24
# 4            57        66        21
# 11           53        64        23
# ...         ...       ...       ...
# 15117        38        44        16
# 15912        39        45        17
# 16308        55        57        16
# 16314        56        58        16
# 16986        56        56        17
#
# [173 rows x 89 columns]

# %%
#Calculate the mean values for each position:
position_means2 = Fifa_Champions.groupby(['Positions Played'])['Overall'].mean().reset_index()

#Rename the "Overall" column with the position_means DataFrame to "Mean Overall".
position_means2.rename(columns={'Overall': 'Mean Overall'}, inplace=True)

#Merge the mean values back into your initial DataFrame based on the "Club Position" column:
Fifa_Champions = Fifa_Champions.merge(position_means2, on='Positions Played', how='left')

Fifa_Champions
# Out:
#               Known As                   Full Name  Overall  Potential  \
# 0             L. Messi                Lionel Messi       91         91
# 1       R. Lewandowski          Robert Lewandowski       91         91
# 2         K. De Bruyne             Kevin De Bruyne       91         91
# 3            K. Mbappé               Kylian Mbappé       91         95
# 4            Neymar Jr  Neymar da Silva Santos Jr.       89         89
# ..                 ...                         ...      ...        ...
# 168          B. Knight                  Ben Knight       60         74
# 169  A. Cozier-Duberry       Amario Cozier-Duberry       59         78
# 170       A. Robertson              Alex Robertson       58         78
# 171  J. Wilson-Esbrand       Joshua Wilson-Esbrand       58         76
# 172           L. Sousa                  Lino Sousa       56         80
#
#      Value(in Euro) Positions Played Best Position Nationality  \
# 0          54000000               RW           CAM   Argentina
# 1          84000000               ST            ST      Poland
# 2         107500000           CM,CAM            CM     Belgium
# 3         190500000            ST,LW            ST      France
# 4          99500000               LW            LW      Brazil
# ..              ...              ...           ...         ...
# 168          600000               RW           CAM     England
# 169          550000           LM,CAM            LM     England
# 170          575000               CM           CAM     England
# 171          500000               LB            LB     England
# 172          425000               LB            LB     England
#
#                                            Image Link  Age  ...  CM Rating  \
# 0    https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         88
# 1    https://cdn.sofifa.net/players/188/545/23_60.png   33  ...         83
# 2    https://cdn.sofifa.net/players/192/985/23_60.png   31  ...         91
# 3    https://cdn.sofifa.net/players/231/747/23_60.png   23  ...         84
# 4    https://cdn.sofifa.net/players/190/871/23_60.png   30  ...         85
# ..                                                ...  ...  ...        ...
# 168  https://cdn.sofifa.net/players/263/955/23_60.png   20  ...         53
# 169  https://cdn.sofifa.net/players/271/743/23_60.png   17  ...         53
# 170  https://cdn.sofifa.net/players/259/677/23_60.png   19  ...         60
# 171  https://cdn.sofifa.net/players/264/681/23_60.png   19  ...         50
# 172  https://cdn.sofifa.net/players/271/808/23_60.png   17  ...         48
#
#      RM Rating  LWB Rating  CDM Rating RWB Rating  LB Rating  CB Rating  \
# 0           91          67          66         67         62         53
# 1           86          67          69         67         64         63
# 2           91          82          82         82         78         72
# 3           92          70          66         70         66         57
# 4           89          69          66         69         64         53
# ..         ...         ...         ...        ...        ...        ...
# 168         60          47          43         47         44         38
# 169         60          48          44         48         45         39
# 170         61          57          58         57         57         55
# 171         56          58          53         58         58         56
# 172         52          56          52         56         56         56
#
#     RB Rating GK Rating Mean Overall
# 0          62        22    70.000000
# 1          64        22    79.454545
# 2          78        24    85.666667
# 3          66        21    77.000000
# 4          64        23    80.666667
# ..        ...       ...          ...
# 168        44        16    70.000000
# 169        45        17    69.500000
# 170        57        16    79.857143
# 171        58        16    73.400000
# 172        56        17    73.400000
#
# [173 rows x 90 columns]

# %%
Fifa_Champions = Fifa_Champions[['Known As', 'Overall','Mean Overall', 'Potential','Positions Played','Club Name', 'Value(in Euro)','Age', 'Best Position', 'Wage(in Euro)', 'Release Clause',
       'Club Position', 'Contract Until', 'Joined On', 'On Loan',
       'National Team Name', 'ST Rating', 'LW Rating', 'LF Rating',
       'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
       'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
       'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality']]

Fifa_Champions
# Out:
#               Known As  Overall  Mean Overall  Potential Positions Played  \
# 0             L. Messi       91     70.000000         91               RW
# 1       R. Lewandowski       91     79.454545         91               ST
# 2         K. De Bruyne       91     85.666667         91           CM,CAM
# 3            K. Mbappé       91     77.000000         95            ST,LW
# 4            Neymar Jr       89     80.666667         89               LW
# ..                 ...      ...           ...        ...              ...
# 168          B. Knight       60     70.000000         74               RW
# 169  A. Cozier-Duberry       59     69.500000         78           LM,CAM
# 170       A. Robertson       58     79.857143         78               CM
# 171  J. Wilson-Esbrand       58     73.400000         76               LB
# 172           L. Sousa       56     73.400000         80               LB
#
#                Club Name  Value(in Euro)  Age Best Position  Wage(in Euro)  \
# 0    Paris Saint-Germain        54000000   35           CAM         195000
# 1           FC Barcelona        84000000   33            ST         420000
# 2        Manchester City       107500000   31            CM         350000
# 3    Paris Saint-Germain       190500000   23            ST         230000
# 4    Paris Saint-Germain        99500000   30            LW         200000
# ..                   ...             ...  ...           ...            ...
# 168      Manchester City          600000   20           CAM          12000
# 169              Arsenal          550000   17            LM           1000
# 170      Manchester City          575000   19           CAM           8000
# 171      Manchester City          500000   19            LB           7000
# 172              Arsenal          425000   17            LB            500
#
#      ...  CM Rating RM Rating LWB Rating  CDM Rating RWB Rating LB Rating  \
# 0    ...         88        91         67          66         67        62
# 1    ...         83        86         67          69         67        64
# 2    ...         91        91         82          82         82        78
# 3    ...         84        92         70          66         70        66
# 4    ...         85        89         69          66         69        64
# ..   ...        ...       ...        ...         ...        ...       ...
# 168  ...         53        60         47          43         47        44
# 169  ...         53        60         48          44         48        45
# 170  ...         60        61         57          58         57        57
# 171  ...         50        56         58          53         58        58
# 172  ...         48        52         56          52         56        56
#
#      CB Rating  RB Rating  GK Rating  Nationality
# 0           53         62         22    Argentina
# 1           63         64         22       Poland
# 2           72         78         24      Belgium
# 3           57         66         21       France
# 4           53         64         23       Brazil
# ..         ...        ...        ...          ...
# 168         38         44         16      England
# 169         39         45         17      England
# 170         55         57         16      England
# 171         56         58         16      England
# 172         56         56         17      England
#
# [173 rows x 34 columns]

# %%
#Checking again the overall score of our players in Manchester City compared to the mean of the Champions League top teams.

Fifa_MC2 = Fifa_Champions.loc[Fifa_Champions['Club Name'] == "Manchester City"]
Fifa_MC2
# Out:
#               Known As  Overall  Mean Overall  Potential Positions Played  \
# 2         K. De Bruyne       91     85.666667         91           CM,CAM
# 5              Ederson       89     76.473684         91               GK
# 6           Rúben Dias       88     80.083333         91               CB
# 7           E. Haaland       88     79.454545         94               ST
# 9       Bernardo Silva       88     84.000000         88           CAM,CM
# 10        João Cancelo       88     88.000000         88            LB,RB
# 14               Rodri       87     79.000000         89              CDM
# 18           R. Mahrez       86     84.500000         86            RW,RM
# 19          A. Laporte       86     80.083333         87               CB
# 24         İ. Gündoğan       85     73.555556         85           CM,CDM
# 25           K. Walker       85     76.000000         85               RB
# 30            P. Foden       85     85.000000         92        LW,CF,CAM
# 35         J. Grealish       84     84.000000         84        LW,LM,CAM
# 54           J. Stones       83     80.083333         84               CB
# 66           M. Akanji       81     80.083333         82               CB
# 71         K. Phillips       81     79.777778         85           CDM,CM
# 77           S. Ortega       80     76.473684         80               GK
# 92          J. Álvarez       78     78.000000         86         ST,RW,LW
# 95              N. Aké       78     72.500000         80            CB,LB
# 118       Sergio Gómez       74     74.000000         83         LB,RM,LM
# 147          C. Palmer       67     67.000000         85        RW,CAM,CF
# 149          M. Rogers       66     71.333333         82            LW,RW
# 153          S. Carson       65     76.473684         65               GK
# 167           R. Lewis       61     76.000000         82               RB
# 168          B. Knight       60     70.000000         74               RW
# 170       A. Robertson       58     79.857143         78               CM
# 171  J. Wilson-Esbrand       58     73.400000         76               LB
#
#            Club Name  Value(in Euro)  Age Best Position  Wage(in Euro)  ...  \
# 2    Manchester City       107500000   31            CM         350000  ...
# 5    Manchester City        88000000   28            GK         210000  ...
# 6    Manchester City       107500000   25            CB         230000  ...
# 7    Manchester City       148000000   21            ST         220000  ...
# 9    Manchester City        97500000   27           CAM         260000  ...
# 10   Manchester City        82500000   28            LB         250000  ...
# 14   Manchester City        88500000   26           CDM         200000  ...
# 18   Manchester City        56500000   31            RW         220000  ...
# 19   Manchester City        64500000   28            CB         195000  ...
# 24   Manchester City        44000000   31            CM         185000  ...
# 25   Manchester City        37500000   32            RB         170000  ...
# 30   Manchester City       109500000   22           CAM         180000  ...
# 35   Manchester City        46000000   26            LW         185000  ...
# 54   Manchester City        34500000   28            CB         150000  ...
# 66   Manchester City        26500000   26            CB         120000  ...
# 71   Manchester City        32000000   26           CDM         120000  ...
# 77   Manchester City        14500000   29            GK          95000  ...
# 92   Manchester City        32000000   22           CAM         100000  ...
# 95   Manchester City        15000000   27            CB          95000  ...
# 118  Manchester City         9000000   21           CAM          53000  ...
# 147  Manchester City         2700000   20           CAM          26000  ...
# 149  Manchester City         2200000   19            RM          17000  ...
# 153  Manchester City           80000   36            GK          11000  ...
# 167  Manchester City         1000000   17            RB            650  ...
# 168  Manchester City          600000   20           CAM          12000  ...
# 170  Manchester City          575000   19           CAM           8000  ...
# 171  Manchester City          500000   19            LB           7000  ...
#
#      CM Rating RM Rating LWB Rating  CDM Rating RWB Rating LB Rating  \
# 2           91        91         82          82         82        78
# 5           52        47         40          47         40        39
# 6           73        67         81          86         81        83
# 7           76        80         65          67         65        64
# 9           86        88         79          77         79        75
# 10          87        88         88          86         88        87
# 14          86        79         82          87         82        82
# 18          81        86         67          64         67        62
# 19          77        70         80          85         80        81
# 24          85        85         80          83         80        78
# 25          81        81         85          84         85        85
# 30          85        87         75          74         75        72
# 35          83        84         71          70         71        66
# 54          76        73         80          83         80        81
# 66          74        70         78          82         78        80
# 71          80        76         80          82         80        79
# 77          43        39         35          40         35        34
# 92          78        81         69          69         69        67
# 95          74        71         78          79         78        79
# 118         75        75         75          74         75        74
# 147         64        68         59          57         59        57
# 149         62        67         57          54         57        55
# 153         28        27         26          27         26        26
# 167         49        55         60          54         60        61
# 168         53        60         47          43         47        44
# 170         60        61         57          58         57        57
# 171         50        56         58          53         58        58
#
#      CB Rating  RB Rating  GK Rating  Nationality
# 2           72         78         24      Belgium
# 5           38         39         90       Brazil
# 6           90         83         21     Portugal
# 7           65         64         22       Norway
# 9           67         75         21     Portugal
# 10          82         87         22     Portugal
# 14          85         82         21        Spain
# 18          52         62         21      Algeria
# 19          87         81         21        Spain
# 24          75         78         22      Germany
# 25          84         85         22      England
# 30          62         72         22      England
# 35          57         66         21      England
# 54          84         81         20      England
# 66          82         80         19  Switzerland
# 71          81         79         20      England
# 77          35         34         80      Germany
# 92          64         67         19    Argentina
# 95          80         79         21  Netherlands
# 118         69         74         19        Spain
# 147         52         57         17      England
# 149         50         55         18      England
# 153         29         26         65      England
# 167         59         61         19      England
# 168         38         44         16      England
# 170         55         57         16      England
# 171         56         58         16      England
#
# [27 rows x 34 columns]

# %%
Fifa_MC2["Real_OScore"] = (Fifa_MC2["Overall"] + Fifa_MC2["Potential"])/ 2

Fifa_MC2
# Out:
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\3768540343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_MC2["Real_OScore"] = (Fifa_MC2["Overall"] + Fifa_MC2["Potential"])/ 2
#               Known As  Overall  Mean Overall  Potential Positions Played  \
# 2         K. De Bruyne       91     85.666667         91           CM,CAM
# 5              Ederson       89     76.473684         91               GK
# 6           Rúben Dias       88     80.083333         91               CB
# 7           E. Haaland       88     79.454545         94               ST
# 9       Bernardo Silva       88     84.000000         88           CAM,CM
# 10        João Cancelo       88     88.000000         88            LB,RB
# 14               Rodri       87     79.000000         89              CDM
# 18           R. Mahrez       86     84.500000         86            RW,RM
# 19          A. Laporte       86     80.083333         87               CB
# 24         İ. Gündoğan       85     73.555556         85           CM,CDM
# 25           K. Walker       85     76.000000         85               RB
# 30            P. Foden       85     85.000000         92        LW,CF,CAM
# 35         J. Grealish       84     84.000000         84        LW,LM,CAM
# 54           J. Stones       83     80.083333         84               CB
# 66           M. Akanji       81     80.083333         82               CB
# 71         K. Phillips       81     79.777778         85           CDM,CM
# 77           S. Ortega       80     76.473684         80               GK
# 92          J. Álvarez       78     78.000000         86         ST,RW,LW
# 95              N. Aké       78     72.500000         80            CB,LB
# 118       Sergio Gómez       74     74.000000         83         LB,RM,LM
# 147          C. Palmer       67     67.000000         85        RW,CAM,CF
# 149          M. Rogers       66     71.333333         82            LW,RW
# 153          S. Carson       65     76.473684         65               GK
# 167           R. Lewis       61     76.000000         82               RB
# 168          B. Knight       60     70.000000         74               RW
# 170       A. Robertson       58     79.857143         78               CM
# 171  J. Wilson-Esbrand       58     73.400000         76               LB
#
#            Club Name  Value(in Euro)  Age Best Position  Wage(in Euro)  ...  \
# 2    Manchester City       107500000   31            CM         350000  ...
# 5    Manchester City        88000000   28            GK         210000  ...
# 6    Manchester City       107500000   25            CB         230000  ...
# 7    Manchester City       148000000   21            ST         220000  ...
# 9    Manchester City        97500000   27           CAM         260000  ...
# 10   Manchester City        82500000   28            LB         250000  ...
# 14   Manchester City        88500000   26           CDM         200000  ...
# 18   Manchester City        56500000   31            RW         220000  ...
# 19   Manchester City        64500000   28            CB         195000  ...
# 24   Manchester City        44000000   31            CM         185000  ...
# 25   Manchester City        37500000   32            RB         170000  ...
# 30   Manchester City       109500000   22           CAM         180000  ...
# 35   Manchester City        46000000   26            LW         185000  ...
# 54   Manchester City        34500000   28            CB         150000  ...
# 66   Manchester City        26500000   26            CB         120000  ...
# 71   Manchester City        32000000   26           CDM         120000  ...
# 77   Manchester City        14500000   29            GK          95000  ...
# 92   Manchester City        32000000   22           CAM         100000  ...
# 95   Manchester City        15000000   27            CB          95000  ...
# 118  Manchester City         9000000   21           CAM          53000  ...
# 147  Manchester City         2700000   20           CAM          26000  ...
# 149  Manchester City         2200000   19            RM          17000  ...
# 153  Manchester City           80000   36            GK          11000  ...
# 167  Manchester City         1000000   17            RB            650  ...
# 168  Manchester City          600000   20           CAM          12000  ...
# 170  Manchester City          575000   19           CAM           8000  ...
# 171  Manchester City          500000   19            LB           7000  ...
#
#      RM Rating LWB Rating CDM Rating  RWB Rating LB Rating CB Rating  \
# 2           91         82         82          82        78        72
# 5           47         40         47          40        39        38
# 6           67         81         86          81        83        90
# 7           80         65         67          65        64        65
# 9           88         79         77          79        75        67
# 10          88         88         86          88        87        82
# 14          79         82         87          82        82        85
# 18          86         67         64          67        62        52
# 19          70         80         85          80        81        87
# 24          85         80         83          80        78        75
# 25          81         85         84          85        85        84
# 30          87         75         74          75        72        62
# 35          84         71         70          71        66        57
# 54          73         80         83          80        81        84
# 66          70         78         82          78        80        82
# 71          76         80         82          80        79        81
# 77          39         35         40          35        34        35
# 92          81         69         69          69        67        64
# 95          71         78         79          78        79        80
# 118         75         75         74          75        74        69
# 147         68         59         57          59        57        52
# 149         67         57         54          57        55        50
# 153         27         26         27          26        26        29
# 167         55         60         54          60        61        59
# 168         60         47         43          47        44        38
# 170         61         57         58          57        57        55
# 171         56         58         53          58        58        56
#
#      RB Rating  GK Rating  Nationality  Real_OScore
# 2           78         24      Belgium         91.0
# 5           39         90       Brazil         90.0
# 6           83         21     Portugal         89.5
# 7           64         22       Norway         91.0
# 9           75         21     Portugal         88.0
# 10          87         22     Portugal         88.0
# 14          82         21        Spain         88.0
# 18          62         21      Algeria         86.0
# 19          81         21        Spain         86.5
# 24          78         22      Germany         85.0
# 25          85         22      England         85.0
# 30          72         22      England         88.5
# 35          66         21      England         84.0
# 54          81         20      England         83.5
# 66          80         19  Switzerland         81.5
# 71          79         20      England         83.0
# 77          34         80      Germany         80.0
# 92          67         19    Argentina         82.0
# 95          79         21  Netherlands         79.0
# 118         74         19        Spain         78.5
# 147         57         17      England         76.0
# 149         55         18      England         74.0
# 153         26         65      England         65.0
# 167         61         19      England         71.5
# 168         44         16      England         67.0
# 170         57         16      England         68.0
# 171         58         16      England         67.0
#
# [27 rows x 35 columns]

# %%
Fifa_MC2 = Fifa_MC2[['Known As', 'Overall','Potential', 'Real_OScore','Mean Overall', 'Club Name',
       'Value(in Euro)','Positions Played', 'Club Position']]

Fifa_MC2
# Out:
#               Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2         K. De Bruyne       91         91         91.0     85.666667
# 5              Ederson       89         91         90.0     76.473684
# 6           Rúben Dias       88         91         89.5     80.083333
# 7           E. Haaland       88         94         91.0     79.454545
# 9       Bernardo Silva       88         88         88.0     84.000000
# 10        João Cancelo       88         88         88.0     88.000000
# 14               Rodri       87         89         88.0     79.000000
# 18           R. Mahrez       86         86         86.0     84.500000
# 19          A. Laporte       86         87         86.5     80.083333
# 24         İ. Gündoğan       85         85         85.0     73.555556
# 25           K. Walker       85         85         85.0     76.000000
# 30            P. Foden       85         92         88.5     85.000000
# 35         J. Grealish       84         84         84.0     84.000000
# 54           J. Stones       83         84         83.5     80.083333
# 66           M. Akanji       81         82         81.5     80.083333
# 71         K. Phillips       81         85         83.0     79.777778
# 77           S. Ortega       80         80         80.0     76.473684
# 92          J. Álvarez       78         86         82.0     78.000000
# 95              N. Aké       78         80         79.0     72.500000
# 118       Sergio Gómez       74         83         78.5     74.000000
# 147          C. Palmer       67         85         76.0     67.000000
# 149          M. Rogers       66         82         74.0     71.333333
# 153          S. Carson       65         65         65.0     76.473684
# 167           R. Lewis       61         82         71.5     76.000000
# 168          B. Knight       60         74         67.0     70.000000
# 170       A. Robertson       58         78         68.0     79.857143
# 171  J. Wilson-Esbrand       58         76         67.0     73.400000
#
#            Club Name  Value(in Euro) Positions Played Club Position
# 2    Manchester City       107500000           CM,CAM            CM
# 5    Manchester City        88000000               GK            GK
# 6    Manchester City       107500000               CB            CB
# 7    Manchester City       148000000               ST            ST
# 9    Manchester City        97500000           CAM,CM            RW
# 10   Manchester City        82500000            LB,RB            LB
# 14   Manchester City        88500000              CDM           CDM
# 18   Manchester City        56500000            RW,RM           SUB
# 19   Manchester City        64500000               CB            CB
# 24   Manchester City        44000000           CM,CDM            CM
# 25   Manchester City        37500000               RB            RB
# 30   Manchester City       109500000        LW,CF,CAM            LW
# 35   Manchester City        46000000        LW,LM,CAM           SUB
# 54   Manchester City        34500000               CB           SUB
# 66   Manchester City        26500000               CB           SUB
# 71   Manchester City        32000000           CDM,CM           SUB
# 77   Manchester City        14500000               GK           SUB
# 92   Manchester City        32000000         ST,RW,LW           SUB
# 95   Manchester City        15000000            CB,LB           SUB
# 118  Manchester City         9000000         LB,RM,LM           SUB
# 147  Manchester City         2700000        RW,CAM,CF           SUB
# 149  Manchester City         2200000            LW,RW           RES
# 153  Manchester City           80000               GK           SUB
# 167  Manchester City         1000000               RB           SUB
# 168  Manchester City          600000               RW           RES
# 170  Manchester City          575000               CM           RES
# 171  Manchester City          500000               LB           RES

# %%
Fifa_A2 = Fifa_MC2

Fifa_A2["Age"] = Fifa_Champions["Age"]
Fifa_A2["Wage (in euro)"] = Fifa_Champions["Wage(in Euro)"]
Fifa_A2["Release Clause"] = Fifa_Champions["Release Clause"]
Fifa_A2["Contract Until"] = Fifa_Champions["Contract Until"]

Fifa_A2
# Out:
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Age"] = Fifa_Champions["Age"]
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Wage (in euro)"] = Fifa_Champions["Wage(in Euro)"]
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Release Clause"] = Fifa_Champions["Release Clause"]
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Contract Until"] = Fifa_Champions["Contract Until"]
#               Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2         K. De Bruyne       91         91         91.0     85.666667
# 5              Ederson       89         91         90.0     76.473684
# 6           Rúben Dias       88         91         89.5     80.083333
# 7           E. Haaland       88         94         91.0     79.454545
# 9       Bernardo Silva       88         88         88.0     84.000000
# 10        João Cancelo       88         88         88.0     88.000000
# 14               Rodri       87         89         88.0     79.000000
# 18           R. Mahrez       86         86         86.0     84.500000
# 19          A. Laporte       86         87         86.5     80.083333
# 24         İ. Gündoğan       85         85         85.0     73.555556
# 25           K. Walker       85         85         85.0     76.000000
# 30            P. Foden       85         92         88.5     85.000000
# 35         J. Grealish       84         84         84.0     84.000000
# 54           J. Stones       83         84         83.5     80.083333
# 66           M. Akanji       81         82         81.5     80.083333
# 71         K. Phillips       81         85         83.0     79.777778
# 77           S. Ortega       80         80         80.0     76.473684
# 92          J. Álvarez       78         86         82.0     78.000000
# 95              N. Aké       78         80         79.0     72.500000
# 118       Sergio Gómez       74         83         78.5     74.000000
# 147          C. Palmer       67         85         76.0     67.000000
# 149          M. Rogers       66         82         74.0     71.333333
# 153          S. Carson       65         65         65.0     76.473684
# 167           R. Lewis       61         82         71.5     76.000000
# 168          B. Knight       60         74         67.0     70.000000
# 170       A. Robertson       58         78         68.0     79.857143
# 171  J. Wilson-Esbrand       58         76         67.0     73.400000
#
#            Club Name  Value(in Euro) Positions Played Club Position  Age  \
# 2    Manchester City       107500000           CM,CAM            CM   31
# 5    Manchester City        88000000               GK            GK   28
# 6    Manchester City       107500000               CB            CB   25
# 7    Manchester City       148000000               ST            ST   21
# 9    Manchester City        97500000           CAM,CM            RW   27
# 10   Manchester City        82500000            LB,RB            LB   28
# 14   Manchester City        88500000              CDM           CDM   26
# 18   Manchester City        56500000            RW,RM           SUB   31
# 19   Manchester City        64500000               CB            CB   28
# 24   Manchester City        44000000           CM,CDM            CM   31
# 25   Manchester City        37500000               RB            RB   32
# 30   Manchester City       109500000        LW,CF,CAM            LW   22
# 35   Manchester City        46000000        LW,LM,CAM           SUB   26
# 54   Manchester City        34500000               CB           SUB   28
# 66   Manchester City        26500000               CB           SUB   26
# 71   Manchester City        32000000           CDM,CM           SUB   26
# 77   Manchester City        14500000               GK           SUB   29
# 92   Manchester City        32000000         ST,RW,LW           SUB   22
# 95   Manchester City        15000000            CB,LB           SUB   27
# 118  Manchester City         9000000         LB,RM,LM           SUB   21
# 147  Manchester City         2700000        RW,CAM,CF           SUB   20
# 149  Manchester City         2200000            LW,RW           RES   19
# 153  Manchester City           80000               GK           SUB   36
# 167  Manchester City         1000000               RB           SUB   17
# 168  Manchester City          600000               RW           RES   20
# 170  Manchester City          575000               CM           RES   19
# 171  Manchester City          500000               LB           RES   19
#
#      Wage (in euro)  Release Clause Contract Until
# 2            350000       198900000           2025
# 5            210000       169400000           2026
# 6            230000       206900000           2027
# 7            220000       303400000           2027
# 9            260000       180400000           2025
# 10           250000       152600000           2027
# 14           200000       170400000           2027
# 18           220000       104500000           2025
# 19           195000       124200000           2025
# 24           185000        81400000           2023
# 25           170000        69400000           2024
# 30           180000       224500000           2024
# 35           185000        85100000           2027
# 54           150000        66400000           2026
# 66           120000        51000000           2023
# 71           120000        61600000           2028
# 77            95000        26800000           2025
# 92           100000        65599999           2027
# 95            95000        28900000           2025
# 118           53000        18500000           2026
# 147           26000         6700000           2026
# 149           17000         5400000           2024
# 153           11000          148000           2023
# 167             650         2900000           2024
# 168           12000         1500000           2025
# 170            8000         1600000           2023
# 171            7000         1200000           2027

# %%
#Creating a new column with a boolean analysis to highlight players with a Real_OScore below the mean of the Champions leage top 10 teams.

Fifa_MC2["A1_Transfer?"] = np.where(Fifa_MC2["Real_OScore"] < Fifa_MC2["Mean Overall"], True, False)
Fifa_MC2
# Out:
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\339846444.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_MC2["A1_Transfer?"] = np.where(Fifa_MC2["Real_OScore"] < Fifa_MC2["Mean Overall"], True, False)
#               Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2         K. De Bruyne       91         91         91.0     85.666667
# 5              Ederson       89         91         90.0     76.473684
# 6           Rúben Dias       88         91         89.5     80.083333
# 7           E. Haaland       88         94         91.0     79.454545
# 9       Bernardo Silva       88         88         88.0     84.000000
# 10        João Cancelo       88         88         88.0     88.000000
# 14               Rodri       87         89         88.0     79.000000
# 18           R. Mahrez       86         86         86.0     84.500000
# 19          A. Laporte       86         87         86.5     80.083333
# 24         İ. Gündoğan       85         85         85.0     73.555556
# 25           K. Walker       85         85         85.0     76.000000
# 30            P. Foden       85         92         88.5     85.000000
# 35         J. Grealish       84         84         84.0     84.000000
# 54           J. Stones       83         84         83.5     80.083333
# 66           M. Akanji       81         82         81.5     80.083333
# 71         K. Phillips       81         85         83.0     79.777778
# 77           S. Ortega       80         80         80.0     76.473684
# 92          J. Álvarez       78         86         82.0     78.000000
# 95              N. Aké       78         80         79.0     72.500000
# 118       Sergio Gómez       74         83         78.5     74.000000
# 147          C. Palmer       67         85         76.0     67.000000
# 149          M. Rogers       66         82         74.0     71.333333
# 153          S. Carson       65         65         65.0     76.473684
# 167           R. Lewis       61         82         71.5     76.000000
# 168          B. Knight       60         74         67.0     70.000000
# 170       A. Robertson       58         78         68.0     79.857143
# 171  J. Wilson-Esbrand       58         76         67.0     73.400000
#
#            Club Name  Value(in Euro) Positions Played Club Position  Age  \
# 2    Manchester City       107500000           CM,CAM            CM   31
# 5    Manchester City        88000000               GK            GK   28
# 6    Manchester City       107500000               CB            CB   25
# 7    Manchester City       148000000               ST            ST   21
# 9    Manchester City        97500000           CAM,CM            RW   27
# 10   Manchester City        82500000            LB,RB            LB   28
# 14   Manchester City        88500000              CDM           CDM   26
# 18   Manchester City        56500000            RW,RM           SUB   31
# 19   Manchester City        64500000               CB            CB   28
# 24   Manchester City        44000000           CM,CDM            CM   31
# 25   Manchester City        37500000               RB            RB   32
# 30   Manchester City       109500000        LW,CF,CAM            LW   22
# 35   Manchester City        46000000        LW,LM,CAM           SUB   26
# 54   Manchester City        34500000               CB           SUB   28
# 66   Manchester City        26500000               CB           SUB   26
# 71   Manchester City        32000000           CDM,CM           SUB   26
# 77   Manchester City        14500000               GK           SUB   29
# 92   Manchester City        32000000         ST,RW,LW           SUB   22
# 95   Manchester City        15000000            CB,LB           SUB   27
# 118  Manchester City         9000000         LB,RM,LM           SUB   21
# 147  Manchester City         2700000        RW,CAM,CF           SUB   20
# 149  Manchester City         2200000            LW,RW           RES   19
# 153  Manchester City           80000               GK           SUB   36
# 167  Manchester City         1000000               RB           SUB   17
# 168  Manchester City          600000               RW           RES   20
# 170  Manchester City          575000               CM           RES   19
# 171  Manchester City          500000               LB           RES   19
#
#      Wage (in euro)  Release Clause Contract Until  A1_Transfer?
# 2            350000       198900000           2025         False
# 5            210000       169400000           2026         False
# 6            230000       206900000           2027         False
# 7            220000       303400000           2027         False
# 9            260000       180400000           2025         False
# 10           250000       152600000           2027         False
# 14           200000       170400000           2027         False
# 18           220000       104500000           2025         False
# 19           195000       124200000           2025         False
# 24           185000        81400000           2023         False
# 25           170000        69400000           2024         False
# 30           180000       224500000           2024         False
# 35           185000        85100000           2027         False
# 54           150000        66400000           2026         False
# 66           120000        51000000           2023         False
# 71           120000        61600000           2028         False
# 77            95000        26800000           2025         False
# 92           100000        65599999           2027         False
# 95            95000        28900000           2025         False
# 118           53000        18500000           2026         False
# 147           26000         6700000           2026         False
# 149           17000         5400000           2024         False
# 153           11000          148000           2023          True
# 167             650         2900000           2024          True
# 168           12000         1500000           2025          True
# 170            8000         1600000           2023          True
# 171            7000         1200000           2027          True

# %%
"""According to this first analysis, the players to transfer are the following:

S. Carson, R. Lewis, B. Knight, A. Robertson, J. Wilson-Esbrand

"""

# %%
#Analysis

# %%
Fifa_A2 = Fifa_MC2

Fifa_A2["Age"] = Fifa_Champions["Age"]
Fifa_A2["Wage (in euro)"] = Fifa_Champions["Wage(in Euro)"]
Fifa_A2["Release Clause"] = Fifa_Champions["Release Clause"]
Fifa_A2["Contract Until"] = Fifa_Champions["Contract Until"]

Fifa_A2
# Out:
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Age"] = Fifa_Champions["Age"]
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Wage (in euro)"] = Fifa_Champions["Wage(in Euro)"]
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Release Clause"] = Fifa_Champions["Release Clause"]
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\136522090.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_A2["Contract Until"] = Fifa_Champions["Contract Until"]
#               Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2         K. De Bruyne       91         91         91.0     85.666667
# 5              Ederson       89         91         90.0     76.473684
# 6           Rúben Dias       88         91         89.5     80.083333
# 7           E. Haaland       88         94         91.0     79.454545
# 9       Bernardo Silva       88         88         88.0     84.000000
# 10        João Cancelo       88         88         88.0     88.000000
# 14               Rodri       87         89         88.0     79.000000
# 18           R. Mahrez       86         86         86.0     84.500000
# 19          A. Laporte       86         87         86.5     80.083333
# 24         İ. Gündoğan       85         85         85.0     73.555556
# 25           K. Walker       85         85         85.0     76.000000
# 30            P. Foden       85         92         88.5     85.000000
# 35         J. Grealish       84         84         84.0     84.000000
# 54           J. Stones       83         84         83.5     80.083333
# 66           M. Akanji       81         82         81.5     80.083333
# 71         K. Phillips       81         85         83.0     79.777778
# 77           S. Ortega       80         80         80.0     76.473684
# 92          J. Álvarez       78         86         82.0     78.000000
# 95              N. Aké       78         80         79.0     72.500000
# 118       Sergio Gómez       74         83         78.5     74.000000
# 147          C. Palmer       67         85         76.0     67.000000
# 149          M. Rogers       66         82         74.0     71.333333
# 153          S. Carson       65         65         65.0     76.473684
# 167           R. Lewis       61         82         71.5     76.000000
# 168          B. Knight       60         74         67.0     70.000000
# 170       A. Robertson       58         78         68.0     79.857143
# 171  J. Wilson-Esbrand       58         76         67.0     73.400000
#
#            Club Name  Value(in Euro) Positions Played Club Position  Age  \
# 2    Manchester City       107500000           CM,CAM            CM   31
# 5    Manchester City        88000000               GK            GK   28
# 6    Manchester City       107500000               CB            CB   25
# 7    Manchester City       148000000               ST            ST   21
# 9    Manchester City        97500000           CAM,CM            RW   27
# 10   Manchester City        82500000            LB,RB            LB   28
# 14   Manchester City        88500000              CDM           CDM   26
# 18   Manchester City        56500000            RW,RM           SUB   31
# 19   Manchester City        64500000               CB            CB   28
# 24   Manchester City        44000000           CM,CDM            CM   31
# 25   Manchester City        37500000               RB            RB   32
# 30   Manchester City       109500000        LW,CF,CAM            LW   22
# 35   Manchester City        46000000        LW,LM,CAM           SUB   26
# 54   Manchester City        34500000               CB           SUB   28
# 66   Manchester City        26500000               CB           SUB   26
# 71   Manchester City        32000000           CDM,CM           SUB   26
# 77   Manchester City        14500000               GK           SUB   29
# 92   Manchester City        32000000         ST,RW,LW           SUB   22
# 95   Manchester City        15000000            CB,LB           SUB   27
# 118  Manchester City         9000000         LB,RM,LM           SUB   21
# 147  Manchester City         2700000        RW,CAM,CF           SUB   20
# 149  Manchester City         2200000            LW,RW           RES   19
# 153  Manchester City           80000               GK           SUB   36
# 167  Manchester City         1000000               RB           SUB   17
# 168  Manchester City          600000               RW           RES   20
# 170  Manchester City          575000               CM           RES   19
# 171  Manchester City          500000               LB           RES   19
#
#      Wage (in euro)  Release Clause Contract Until  A1_Transfer?
# 2            350000       198900000           2025         False
# 5            210000       169400000           2026         False
# 6            230000       206900000           2027         False
# 7            220000       303400000           2027         False
# 9            260000       180400000           2025         False
# 10           250000       152600000           2027         False
# 14           200000       170400000           2027         False
# 18           220000       104500000           2025         False
# 19           195000       124200000           2025         False
# 24           185000        81400000           2023         False
# 25           170000        69400000           2024         False
# 30           180000       224500000           2024         False
# 35           185000        85100000           2027         False
# 54           150000        66400000           2026         False
# 66           120000        51000000           2023         False
# 71           120000        61600000           2028         False
# 77            95000        26800000           2025         False
# 92           100000        65599999           2027         False
# 95            95000        28900000           2025         False
# 118           53000        18500000           2026         False
# 147           26000         6700000           2026         False
# 149           17000         5400000           2024         False
# 153           11000          148000           2023          True
# 167             650         2900000           2024          True
# 168           12000         1500000           2025          True
# 170            8000         1600000           2023          True
# 171            7000         1200000           2027          True

# %%
Fifa_CU = Fifa_A2[Fifa_A2['Contract Until'].isin(["2023","2024","2025"])]
Fifa_CU
# Out:
#            Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2      K. De Bruyne       91         91         91.0     85.666667
# 9    Bernardo Silva       88         88         88.0     84.000000
# 18        R. Mahrez       86         86         86.0     84.500000
# 19       A. Laporte       86         87         86.5     80.083333
# 24      İ. Gündoğan       85         85         85.0     73.555556
# 25        K. Walker       85         85         85.0     76.000000
# 30         P. Foden       85         92         88.5     85.000000
# 66        M. Akanji       81         82         81.5     80.083333
# 77        S. Ortega       80         80         80.0     76.473684
# 95           N. Aké       78         80         79.0     72.500000
# 149       M. Rogers       66         82         74.0     71.333333
# 153       S. Carson       65         65         65.0     76.473684
# 167        R. Lewis       61         82         71.5     76.000000
# 168       B. Knight       60         74         67.0     70.000000
# 170    A. Robertson       58         78         68.0     79.857143
#
#            Club Name  Value(in Euro) Positions Played Club Position  Age  \
# 2    Manchester City       107500000           CM,CAM            CM   31
# 9    Manchester City        97500000           CAM,CM            RW   27
# 18   Manchester City        56500000            RW,RM           SUB   31
# 19   Manchester City        64500000               CB            CB   28
# 24   Manchester City        44000000           CM,CDM            CM   31
# 25   Manchester City        37500000               RB            RB   32
# 30   Manchester City       109500000        LW,CF,CAM            LW   22
# 66   Manchester City        26500000               CB           SUB   26
# 77   Manchester City        14500000               GK           SUB   29
# 95   Manchester City        15000000            CB,LB           SUB   27
# 149  Manchester City         2200000            LW,RW           RES   19
# 153  Manchester City           80000               GK           SUB   36
# 167  Manchester City         1000000               RB           SUB   17
# 168  Manchester City          600000               RW           RES   20
# 170  Manchester City          575000               CM           RES   19
#
#      Wage (in euro)  Release Clause Contract Until  A1_Transfer?
# 2            350000       198900000           2025         False
# 9            260000       180400000           2025         False
# 18           220000       104500000           2025         False
# 19           195000       124200000           2025         False
# 24           185000        81400000           2023         False
# 25           170000        69400000           2024         False
# 30           180000       224500000           2024         False
# 66           120000        51000000           2023         False
# 77            95000        26800000           2025         False
# 95            95000        28900000           2025         False
# 149           17000         5400000           2024         False
# 153           11000          148000           2023          True
# 167             650         2900000           2024          True
# 168           12000         1500000           2025          True
# 170            8000         1600000           2023          True

# %%
age_threshold = 25
oscore_threshold = 5  # determine the difference from the mean that we will target.
mean_overall = Fifa_CU['Mean Overall']  # Store the mean overall in a variable for efficiency.

highlight_mask = (
    (Fifa_CU['Age'] > age_threshold) &  # Age condition
    (
        (abs(Fifa_CU['Real_OScore'] - mean_overall) <= oscore_threshold) |  # Real_OScore condition
        (Fifa_CU['Real_OScore'] < mean_overall)  # Include players with Real_OScore below the mean
    )
)

# Create a new column "A2_Transfer?" with True for the players we will transfer, and False otherwise.
Fifa_CU['A2_Transfer?'] = highlight_mask

Fifa_CU
# Out:
# C:\Users\withl\AppData\Local\Temp\ipykernel_27880\3934476734.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fifa_CU['A2_Transfer?'] = highlight_mask
#            Known As  Overall  Potential  Real_OScore  Mean Overall  \
# 2      K. De Bruyne       91         91         91.0     85.666667
# 9    Bernardo Silva       88         88         88.0     84.000000
# 18        R. Mahrez       86         86         86.0     84.500000
# 19       A. Laporte       86         87         86.5     80.083333
# 24      İ. Gündoğan       85         85         85.0     73.555556
# 25        K. Walker       85         85         85.0     76.000000
# 30         P. Foden       85         92         88.5     85.000000
# 66        M. Akanji       81         82         81.5     80.083333
# 77        S. Ortega       80         80         80.0     76.473684
# 95           N. Aké       78         80         79.0     72.500000
# 149       M. Rogers       66         82         74.0     71.333333
# 153       S. Carson       65         65         65.0     76.473684
# 167        R. Lewis       61         82         71.5     76.000000
# 168       B. Knight       60         74         67.0     70.000000
# 170    A. Robertson       58         78         68.0     79.857143
#
#            Club Name  Value(in Euro) Positions Played Club Position  Age  \
# 2    Manchester City       107500000           CM,CAM            CM   31
# 9    Manchester City        97500000           CAM,CM            RW   27
# 18   Manchester City        56500000            RW,RM           SUB   31
# 19   Manchester City        64500000               CB            CB   28
# 24   Manchester City        44000000           CM,CDM            CM   31
# 25   Manchester City        37500000               RB            RB   32
# 30   Manchester City       109500000        LW,CF,CAM            LW   22
# 66   Manchester City        26500000               CB           SUB   26
# 77   Manchester City        14500000               GK           SUB   29
# 95   Manchester City        15000000            CB,LB           SUB   27
# 149  Manchester City         2200000            LW,RW           RES   19
# 153  Manchester City           80000               GK           SUB   36
# 167  Manchester City         1000000               RB           SUB   17
# 168  Manchester City          600000               RW           RES   20
# 170  Manchester City          575000               CM           RES   19
#
#      Wage (in euro)  Release Clause Contract Until  A1_Transfer?  A2_Transfer?
# 2            350000       198900000           2025         False         False
# 9            260000       180400000           2025         False          True
# 18           220000       104500000           2025         False          True
# 19           195000       124200000           2025         False         False
# 24           185000        81400000           2023         False         False
# 25           170000        69400000           2024         False         False
# 30           180000       224500000           2024         False         False
# 66           120000        51000000           2023         False          True
# 77            95000        26800000           2025         False          True
# 95            95000        28900000           2025         False         False
# 149           17000         5400000           2024         False         False
# 153           11000          148000           2023          True          True
# 167             650         2900000           2024          True         False
# 168           12000         1500000           2025          True         False
# 170            8000         1600000           2023          True         False

# %%
#Budget
# Finding the total budget of MC players by calculating thier total Wages
club_name = 'Manchester City'

Manchester_wage = Fifa_MC[Fifa_['Club Name'] == club_name]

Total_wages_in_Manchester_city = Manchester_wage['Wage (in euro)'].sum()

print(f"The total wages of players in {club_name} is: {Total_wages_in_Manchester_city}")
# Out:
# The total wages of players in Manchester City is: 1918650

# %%
Fifa_MC.columns
# Out:
# Index(['Known As', 'Overall', 'Mean Overall', 'Potential', 'Positions Played',
#        'Club Position', 'Club Name', 'ST Rating', 'LW Rating', 'LF Rating',
#        'CF Rating', 'RF Rating', 'RW Rating', 'CAM Rating', 'LM Rating',
#        'CM Rating', 'RM Rating', 'LWB Rating', 'CDM Rating', 'RWB Rating',
#        'LB Rating', 'CB Rating', 'RB Rating', 'GK Rating', 'Nationality',
#        'Gap_Potential'],
#       dtype='object')

# %%
Fifa_CU.columns
# Out:
# Index(['Known As', 'Overall', 'Potential', 'Real_OScore', 'Mean Overall',
#        'Club Name', 'Value(in Euro)', 'Positions Played', 'Club Position',
#        'Age', 'Wage (in euro)', 'Release Clause', 'Contract Until',
#        'A1_Transfer?', 'A2_Transfer?'],
#       dtype='object')

# %%
Fifa_MC2.columns
# Out:
# Index(['Known As', 'Overall', 'Potential', 'Real_OScore', 'Mean Overall',
#        'Club Name', 'Value(in Euro)', 'Positions Played', 'Club Position',
#        'Age', 'Wage (in euro)', 'Release Clause', 'Contract Until',
#        'A1_Transfer?'],
#       dtype='object')

# %%
total_wage = Fifa_MC2['Wage (in euro)'].sum()
total_wage
# Out:
# 3669650

# %%
total_wage_for_transfers = Fifa_CU[Fifa_CU['A2_Transfer?'] == True]['Wage (in euro)'].sum()
print(total_wage_for_transfers)
# Out:
# 706000

# %%
total_value_for_transfers = Fifa_CU[Fifa_CU['A2_Transfer?'] == True]['Value(in Euro)'].sum()
print(total_value_for_transfers)
# Out:
# 195080000
